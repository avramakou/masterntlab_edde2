# %%
# Γαλάζιες σημαίες ανά χώρα (επίσημα αποτελέσματα 2020)

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Create dataframe
blueflags2020_df = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/blue_flags/Blue Flag sites - Blue Flag.ocr.csv')
blueflags2020_df # Check dataframe -> missing column in comparison with other pages
# Out:
#                Unnamed: 0 Beaches Marinas Boats Awarded sites
# 0             Country * ▼     A ▼     A ▼   A ▼           A T
# 1                   Spain     590      94     5           689
# 2                  Greece     497      14     6           517
# 3                  Turkey     486      22   NaN           508
# 4                   Italy     407      75   NaN           482
# 5                  France     401     106   507           NaN
# 6                Portugal     360      18     9           387
# 7                 Denmark     174      18   192           NaN
# 8                 Croatia      93      29   NaN           122
# 9                 Ireland      82      10   NaN            92
# 10                England      74     NaN    74           NaN
# 11                 Cyprus      66       1    67           NaN
# 12                 Mexico      66       3    25            94
# 13            Netherlands      55     129   NaN           184
# ...

# %%
# Rename headers
blueflags2020_df.rename(columns = {'Unnamed: 0':'Country'}, inplace = True)
blueflags2020_df.head()
# Out:
#        Country Beaches Marinas Boats Awarded sites
# 0  Country * ▼     A ▼     A ▼   A ▼           A T
# 1        Spain     590      94     5           689
# 2       Greece     497      14     6           517
# 3       Turkey     486      22   NaN           508
# 4        Italy     407      75   NaN           482

# %%
# Drop first row
blueflags2020_df = blueflags2020_df.iloc[1:]
blueflags2020_df.head()
# Out:
#   Country Beaches Marinas Boats Awarded sites
# 1   Spain     590      94     5           689
# 2  Greece     497      14     6           517
# 3  Turkey     486      22   NaN           508
# 4   Italy     407      75   NaN           482
# 5  France     401     106   507           NaN

# %%
# Replace all NaN elements with zero number (original table's empty cells are equal to zero)
new_blueflags2020_df = blueflags2020_df.fillna(0)
new_blueflags2020_df
# Out:
#                   Country Beaches Marinas Boats Awarded sites
# 1                   Spain     590      94     5           689
# 2                  Greece     497      14     6           517
# 3                  Turkey     486      22     0           508
# 4                   Italy     407      75     0           482
# 5                  France     401     106   507             0
# 6                Portugal     360      18     9           387
# 7                 Denmark     174      18   192             0
# 8                 Croatia      93      29     0           122
# 9                 Ireland      82      10     0            92
# 10                England      74       0    74             0
# 11                 Cyprus      66       1    67             0
# 12                 Mexico      66       3    25            94
# 13            Netherlands      55     129     0           184
# 14                 Israel      52       2     0            54
# ...

# %%
# Export dataframe to csv file
from google.colab import files
new_blueflags2020_df.to_csv('global_blueflags2020.csv') 
files.download("global_blueflags2020.csv")

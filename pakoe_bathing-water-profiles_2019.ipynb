# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Import drive
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).

# %%
# Μετρήσεις που πραγματοποίησε και δημοσιοποίησε το Πανελλήνιο Κέντρο Οικολογικών Ερευνών (2019)

# %%
# Create dataframe (page 10)
thalasses_df1 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0010.ocr.csv')
thalasses_df1.head() # Check dataframe -> missing column in comparison with other pages
# Out:
#   Unnamed: 0    1\nS ^  ...       Unnamed: 5   ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)
# 0        Α/Α  ο ο °\n<  ...  Εντερόκοκ-\nκοι  ΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 1          1     10:10  ...              150                   A
# 2          2     10:40  ...                6                   A
# 3          3     10:50  ...               12                   Κ
# 4          4     11:00  ...               58                   Κ
#
# [5 rows x 7 columns]

# %%
# Insert extra column (Συντεταγμένες)
thalasses_df1.insert(2, "Συντεταγμένες", ["", "", "", "", "", "", "", "", ""], True)
thalasses_df1.head() # Check dataframe -> successful process
# Out:
#   Unnamed: 0    1\nS ^  ...       Unnamed: 5   ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)
# 0        Α/Α  ο ο °\n<  ...  Εντερόκοκ-\nκοι  ΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 1          1     10:10  ...              150                   A
# 2          2     10:40  ...                6                   A
# 3          3     10:50  ...               12                   Κ
# 4          4     11:00  ...               58                   Κ
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df1.rename(columns = {'Unnamed: 0':'Α/Α', '1\nS ^':'Ώρα Δειγματοληψίας', 
                              'Unnamed: 2':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 4':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)':'Καταλληλότητα (Α/Κ)'}, inplace = True)
thalasses_df1
# Out:
#    Α/Α  ... Καταλληλότητα (Α/Κ)
# 0  Α/Α  ...  ΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 1    1  ...                   A
# 2    2  ...                   A
# 3    3  ...                   Κ
# 4    4  ...                   Κ
# 5    5  ...                   Κ
# 6    6  ...                   A
# 7    7  ...                   Κ
# 8    8  ...                   Κ
#
# [9 rows x 8 columns]

# %%
# Delete odd column (Α/Α)
del thalasses_df1['Α/Α']

# %%
# Drop first row
thalasses_df1 = thalasses_df1.iloc[1:]
thalasses_df1.head()
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              10:10  ...                   A
# 2              10:40  ...                   A
# 3              10:50  ...                   Κ
# 4              11:00  ...                   Κ
# 5              11:10  ...                   Κ
#
# [5 rows x 7 columns]

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df1.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019"], True)
thalasses_df1.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              10:10  ...                   A
# 2              10:40  ...                   A
# 3              10:50  ...                   Κ
# 4              11:00  ...                   Κ
# 5              11:10  ...                   Κ
#
# [5 rows x 8 columns]

# %%
# Insert extra column (Ημ/νία ανάλυσης)
thalasses_df1.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019"], True)
thalasses_df1.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              10:10  ...                   A
# 2              10:40  ...                   A
# 3              10:50  ...                   Κ
# 4              11:00  ...                   Κ
# 5              11:10  ...                   Κ
#
# [5 rows x 9 columns]

# %%
# Create dataframe (page 11)
thalasses_df2 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0011.ocr.csv')
thalasses_df2.tail() # Check dataframe -> missing column in comparison with other pages
# Out:
#      Α/Α 1\ng υ*  ... Unnamed: 5 ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)
# 23  31.0   15:50  ...         10                 Κ
# 24  32.0   16:05  ...          0                 Κ
# 25  33.0   16:15  ...          0                 Κ
# 26  34.0   16:23  ...          0                 Κ
# 27  35.0   16:30  ...          6                 Κ
#
# [5 rows x 7 columns]

# %%
# Insert extra column (Συντεταγμένες)
thalasses_df2.insert(2, "Συντεταγμένες", ["", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", "", ""], True)
thalasses_df2.head() # Check dataframe -> successful process
# Out:
#     Α/Α          1\ng υ*  ...       Unnamed: 5   ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)
# 0   NaN  ο σ*2\n5·^\nI-1  ...  Εντερόκοκ-\nκοι  ΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 1   9.0            12:30  ...               20                   Κ
# 2  10.0            12:45  ...               16                   Κ
# 3  11.0            12:58  ...               10                   Κ
# 4  12.0            13:10  ...               22                   κ
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df2.rename(columns = {'1\ng υ*':'Ώρα Δειγματοληψίας', 
                              'ΘΕΣΗ ΔΕΙΓΜΑΤΟΛΗΨΙΑΣ':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 4':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)':'Καταλληλότητα (Α/Κ)'}, inplace = True)

# %%
# Delete odd column (Α/Α)
del thalasses_df2['Α/Α']

# %%
# Drop first row
thalasses_df2 = thalasses_df2.iloc[1:]
thalasses_df2.head()
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              12:30  ...                   Κ
# 2              12:45  ...                   Κ
# 3              12:58  ...                   Κ
# 4              13:10  ...                   κ
# 5              13:20  ...                   A
#
# [5 rows x 7 columns]

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df2.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019",
                                                       "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019",
                                                       "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019","02/05/2019", 
                                                       "02/05/2019", "02/05/2019", "02/05/2019"], True)
thalasses_df2.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              12:30  ...                   Κ
# 2              12:45  ...                   Κ
# 3              12:58  ...                   Κ
# 4              13:10  ...                   κ
# 5              13:20  ...                   A
#
# [5 rows x 8 columns]

# %%
# Insert extra column (Ημ/νία ανάλυσης)
thalasses_df2.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019",
                                                       "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019",
                                                       "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019", "02/05/2019","02/05/2019", 
                                                       "02/05/2019", "02/05/2019", "02/05/2019"], True)
thalasses_df2.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              12:30  ...                   Κ
# 2              12:45  ...                   Κ
# 3              12:58  ...                   Κ
# 4              13:10  ...                   κ
# 5              13:20  ...                   A
#
# [5 rows x 9 columns]

# %%
# Create dataframe (page 12)
thalasses_df3 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0012.ocr.csv')
thalasses_df3.head() # Check dataframe
# Out:
#    Α/Α  ... ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 0  NaN  ...                                   NaN
# 1    1  ...                                     Κ
# 2    2  ...                                     Κ
# 3    3  ...                                     Κ
# 4    U  ...                                     κ
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df3.rename(columns = {'CT\nΙιΙ\n>':'Συντεταγμένες', 
                                'ΘΕΣΗ ΔΕΙΓΜΑΤΟΛΗΨΙΑΣ':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 6':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)':'Καταλληλότητα (Α/Κ)'}, inplace = True)
thalasses_df3.rename(columns={ thalasses_df3.columns[1]: "Ώρα Δειγματοληψίας" }, inplace = True)
thalasses_df3.head()
# Out:
#    Α/Α  ... Καταλληλότητα (Α/Κ)
# 0  NaN  ...                 NaN
# 1    1  ...                   Κ
# 2    2  ...                   Κ
# 3    3  ...                   Κ
# 4    U  ...                   κ
#
# [5 rows x 8 columns]

# %%
# Delete odd column (Α/Α)
del thalasses_df3['Α/Α']

# %%
# Drop first row
thalasses_df3 = thalasses_df3.iloc[1:]
thalasses_df3.tail() # Check dataframe -> number of rows (9)
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 5              10:65  ...                   κ
# 6              10:55  ...                   κ
# 7              11:00  ...                   κ
# 8              11:10  ...                   κ
# 9              11:25  ...                   κ
#
# [5 rows x 7 columns]

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df3.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019"], True)
thalasses_df3.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              10:10  ...                   Κ
# 2              10:20  ...                   Κ
# 3              10:30  ...                   Κ
# 4              10:38  ...                   κ
# 5              10:65  ...                   κ
#
# [5 rows x 8 columns]

# %%
# Insert extra column (Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df3.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019"], True)
thalasses_df3.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              10:10  ...                   Κ
# 2              10:20  ...                   Κ
# 3              10:30  ...                   Κ
# 4              10:38  ...                   κ
# 5              10:65  ...                   κ
#
# [5 rows x 9 columns]

# %%
# Create dataframe (page 13)
thalasses_df4 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0013.ocr.csv')
thalasses_df4.tail() # Check dataframe -> number of rows (32)
# Out:
#      Α/Α cr\nο\n9-\nc  ... Unnamed: 6 ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 28  37.0        15:10  ...         16                                     κ
# 29  38.0        15:20  ...          2                                     κ
# 30  39.0        15:30  ...         18                                     κ
# 31  40.0        15:40  ...          0                                     κ
# 32  41.0        15:55  ...        130                                     A
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df4.rename(columns = {'cr\nο\n9-\nc':'Ώρα Δειγματοληψίας', 
                                'CT\nΙιΙ\n>':'Συντεταγμένες','ΘΕΣΗ ΔΕΙΓΜΑΤΟΛΗΨΙΑΣ':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 6':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)':'Καταλληλότητα (Α/Κ)'}, inplace = True)

# %%
# Delete odd column (Α/Α)
del thalasses_df4['Α/Α']

# %%
# Drop first row
thalasses_df4 = thalasses_df4.iloc[1:]
thalasses_df4.head()
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              11:35  ...                   Κ
# 2              11:50  ...                   Κ
# 3              11:52  ...                   Κ
# 4              12:15  ...                   A
# 5              12:25  ...                   A
#
# [5 rows x 7 columns]

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df4.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019"], True)

# %%
# Insert extra column (Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df4.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019", "03/05/2019",
                                                       "03/05/2019", "03/05/2019"], True)
thalasses_df4.head() # Check dataframe
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              11:35  ...                   Κ
# 2              11:50  ...                   Κ
# 3              11:52  ...                   Κ
# 4              12:15  ...                   A
# 5              12:25  ...                   A
#
# [5 rows x 9 columns]

# %%
# Create dataframe (page 14)
thalasses_df5 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0014.ocr.csv')
thalasses_df5.tail()
# Out:
#   Unnamed: 0  ... ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 1          1  ...                                     A
# 2          2  ...                                     Κ
# 3          3  ...                                     A
# 4          U  ...                                     Κ
# 5          5  ...                                     Κ
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df5.rename(columns = {'Unnamed: 0':'Α/Α', 
                                'Ώρα\nΔειγματοληψίας':'Ώρα Δειγματοληψίας', 'ΙιΙ\n>':'Συντεταγμένες','Unnamed: 3':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 6':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)':'Καταλληλότητα (Α/Κ)'}, inplace = True)
thalasses_df5.head()
# Out:
#    Α/Α  ... Καταλληλότητα (Α/Κ)
# 0  Α/Α  ...                 NaN
# 1    1  ...                   A
# 2    2  ...                   Κ
# 3    3  ...                   A
# 4    U  ...                   Κ
#
# [5 rows x 8 columns]

# %%
# Drop first row
thalasses_df5 = thalasses_df5.iloc[1:]
thalasses_df5.head() # Check dataframe -> successful process
# Out:
#   Α/Α  ... Καταλληλότητα (Α/Κ)
# 1   1  ...                   A
# 2   2  ...                   Κ
# 3   3  ...                   A
# 4   U  ...                   Κ
# 5   5  ...                   Κ
#
# [5 rows x 8 columns]

# %%
# Delete odd column (Α/Α)
del thalasses_df5['Α/Α']

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df5.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019"], True)

# %%
# Insert extra column (Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df5.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019"], True)
thalasses_df5.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              10:30  ...                   A
# 2              10:40  ...                   Κ
# 3              10:Λ5  ...                   A
# 4              10:50  ...                   Κ
# 5              10:55  ...                   Κ
#
# [5 rows x 9 columns]

# %%
# Create dataframe (page 15)
thalasses_df6 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0015.ocr.csv')
thalasses_df6.head() # Check dataframe -> missing values
# Out:
#    Α/Α           Ο\n§■  ...       Unnamed: 6 ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 0  NaN  Ώρα\nΔειγματολ  ...  Εντερό-\nκοκκοι                                   NaN
# 1  6.0           11:05  ...               10                                     Κ
# 2  7.0           11:15  ...                4                                     Κ
# 3  8.0           11:20  ...               20                                     Κ
# 4  9.0           11:25  ...               14                                     A
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df6.rename(columns = {"CT\n>\n'Μ":'Συντεταγμένες', 'ΘΕΣΗ ΔΕΙΓΜΑΤΟΛΗΨΙΑΣ':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 6':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)':'Καταλληλότητα (Α/Κ)'}, inplace = True)
thalasses_df6.rename(columns={ thalasses_df6.columns[1]: "Ώρα Δειγματοληψίας" }, inplace = True)

# %%
# Drop first row
thalasses_df6 = thalasses_df6.iloc[1:]
thalasses_df6.head()
# Out:
#     Α/Α  ... Καταλληλότητα (Α/Κ)
# 1   6.0  ...                   Κ
# 2   7.0  ...                   Κ
# 3   8.0  ...                   Κ
# 4   9.0  ...                   A
# 5  10.0  ...                   Κ
#
# [5 rows x 8 columns]

# %%
# Delete odd column (Α/Α)
del thalasses_df6['Α/Α']

# %%
# Count rows & columns
thalasses_df6.shape # rows (22)
# Out:
# (22, 7)

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df6.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019"], True)
thalasses_df6.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              11:05  ...                   Κ
# 2              11:15  ...                   Κ
# 3              11:20  ...                   Κ
# 4              11:25  ...                   A
# 5              11:35  ...                   Κ
#
# [5 rows x 8 columns]

# %%
# Insert extra column (Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df6.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019"], True)
thalasses_df6.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              11:05  ...                   Κ
# 2              11:15  ...                   Κ
# 3              11:20  ...                   Κ
# 4              11:25  ...                   A
# 5              11:35  ...                   Κ
#
# [5 rows x 9 columns]

# %%
# Create dataframe (page 16)
thalasses_df7 = pd.read_csv('/gdrive/My Drive/Colab Notebooks/Files/pakoe_2019/Entheto_Thalasses_ΑΤΤΙΚΗ_2019_page-0016.ocr.csv')
thalasses_df7.head() # Check dataframe
# Out:
#   Unnamed: 0  ... ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)
# 0        Α/Α  ...                                   NaN
# 1         28  ...                                     Κ
# 2         29  ...                                     Κ
# 3         30  ...                                     Κ
# 4         31  ...                                     κ
#
# [5 rows x 8 columns]

# %%
# Rename headers
thalasses_df7.rename(columns = {'Unnamed: 0':'Α/Α', "LT\nΟ\n'5-\nc":'Ώρα Δειγματοληψίας', 'CT\nΙιΙ\n>':'Συντεταγμένες', 'ΘΕΣΗ ΔΕΙΓΜΑΤΟΛΗΨΙΑΣ':'Θέση Δειγματοληψίας', 'ΑΡΙΘΜΟΣ ΑΠΟΙΚΙΩΝ\ncfu/ 100 ml':'Αριθμός Αποικιών cfu/100 ml - Κωλοβακτηρίδια κοπράνων', 'Unnamed: 5':'Αριθμός Αποικιών cfu/100 ml - E.coli', 'Unnamed: 6':'Αριθμός Αποικιών cfu/100 ml - Εντερόκοκκοι', 'ΚΑΤΑΛ-\nΛΗΛΑ\n(Κ)\nΑΚΑΤΑΛ-\nΛΗΛΑ\n(Α)':'Καταλληλότητα (Α/Κ)'}, inplace = True)

# %%
# Drop first row
thalasses_df7 = thalasses_df7.iloc[1:]

# %%
# Delete odd column (Α/Α)
del thalasses_df7['Α/Α']

# %%
# Count rows & columns
thalasses_df7.shape # rows (9)
# Out:
# (9, 7)

# %%
# Insert extra column (Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df7.insert(2, "Ημ/νία δειγμ/ας ΗΗ/ΜΜ/ΕΕΕΕ", ["06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019"], True)
thalasses_df7.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              14:20  ...                   Κ
# 2              14:35  ...                   Κ
# 3              14:45  ...                   Κ
# 4              15:00  ...                   κ
# 5              15:20  ...                   Α
#
# [5 rows x 8 columns]

# %%
# Insert extra column # Insert extra column (Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ)
thalasses_df7.insert(3, "Ημ/νία ανάλυσης ΗΗ/ΜΜ/ΕΕΕΕ", ["06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019",
                                                       "06/05/2019", "06/05/2019", "06/05/2019", "06/05/2019"], True)
thalasses_df7.head() # Check dataframe -> successful process
# Out:
#   Ώρα Δειγματοληψίας  ... Καταλληλότητα (Α/Κ)
# 1              14:20  ...                   Κ
# 2              14:35  ...                   Κ
# 3              14:45  ...                   Κ
# 4              15:00  ...                   κ
# 5              15:20  ...                   Α
#
# [5 rows x 9 columns]

# %%
# Concatenate dataframes
# Count rows & columns (check result)
thalasses_df = pd.concat([thalasses_df1, thalasses_df2, thalasses_df3, thalasses_df4, thalasses_df5, thalasses_df6, thalasses_df7], axis=0)
thalasses_df.shape
# Out:
# (112, 9)
